# %%
import torch
import os
import numpy as np
import matplotlib.pyplot as plt

from fairseq.models.transformer import TransformerModel
# Out:
# 2023-01-23 16:17:21 | WARNING | root | Triton is not available, some optimizations will not be enabled.
# Error No module named 'triton'
# 2023-01-23 16:17:21 | WARNING | root | Triton is not available, some optimizations will not be enabled.
# Error No module named 'triton'

# %%
# precision_matrices = torch.load("../checkpoints/precision_matrices_hq.pt")

# fairseq_ckpt = torch.load("../checkpoints/base_checkpoint_best.pt")
# fairseq_model_dict = dict(fairseq_ckpt["model"])

# %%
model = TransformerModel.from_pretrained(
  '../checkpoints',
  checkpoint_file='checkpoint_best.pt',
  data_name_or_path='../../data_bin/v2_distilled_indic_en_bin/final_bin/',
  bpe='subword_nmt',
  bpe_codes='../../data_bin/v2_distilled_indic_en_bin/vocab/bpe_codes.32k.SRC'
)
# Out:
# 2023-01-23 16:22:06 | INFO | fairseq.file_utils | loading archive file ../checkpoints
# 2023-01-23 16:22:06 | INFO | fairseq.tasks.translation | [SRC] dictionary: 35904 types
# 2023-01-23 16:22:06 | INFO | fairseq.tasks.translation | [TGT] dictionary: 32088 types
# ...

# %%
model
# Out:
# GeneratorHubInterface(
#   (models): ModuleList(
#     (0): TransformerModel(
#       (encoder): TransformerEncoderBase(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(35904, 512, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layernorm_embedding): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0): TransformerEncoderLayerBase(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=512, out_features=512, bias=True)
#               (v_proj): Linear(in_features=512, out_features=512, bias=True)
#               (q_proj): Linear(in_features=512, out_features=512, bias=True)
#               (out_proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# ...
